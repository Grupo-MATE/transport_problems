# %%
using Shapefile, Plots, GeometryBasics

# %%
path = "depto_p.shp"
table = Shapefile.Table(path)

# if you only want the geometries and not the metadata in the DBF file
geoms = Shapefile.shapes(table)

montevideo=geoms[1]
plot(geoms[1])

# %%
montevideo.points
# Out:
# 19459-element Vector{Shapefile.Point}:
#  Shapefile.Point(558939.2540000007, 6.1503887080000015e6)
#  Shapefile.Point(558941.7390000001, 6.150392948e6)
#  Shapefile.Point(558967.1057562819, 6.150430486807192e6)
#  Shapefile.Point(558982.7425259445, 6.150453569657645e6)
#  Shapefile.Point(559006.6509999996, 6.150487671999999e6)
#  Shapefile.Point(559015.4880000008, 6.150501112e6)
#  Shapefile.Point(559020.201136875, 6.150509269313778e6)
#  Shapefile.Point(559028.0772851435, 6.150522901044513e6)
#  Shapefile.Point(559043.3339999998, 6.15054901e6)
#  Shapefile.Point(559037.7870000005, 6.150609464e6)
#  Shapefile.Point(559036.7469999986, 6.150611341000001e6)
#  Shapefile.Point(559038.0309999995, 6.15061294e6)
#  Shapefile.Point(559039.8510000007, 6.1506130370000005e6)
#  ⋮
#  Shapefile.Point(558913.5020000013, 6.150334712000002e6)
#  Shapefile.Point(558917.0060000019, 6.150339463e6)
#  Shapefile.Point(558920.1940000011, 6.150343097e6)
#  Shapefile.Point(558923.8190000011, 6.150348097e6)
#  Shapefile.Point(558925.5950000007, 6.1503515200000005e6)
#  Shapefile.Point(558927.5130000003, 6.150356321e6)
#  Shapefile.Point(558929.1579999998, 6.150360678e6)
#  Shapefile.Point(558931.648, 6.150367334e6)
#  Shapefile.Point(558933.4390000012, 6.150374491e6)
#  Shapefile.Point(558935.1009999989, 6.150380539000001e6)
#  Shapefile.Point(558936.5700000012, 6.150384188e6)
#  Shapefile.Point(558939.2540000007, 6.1503887080000015e6)
