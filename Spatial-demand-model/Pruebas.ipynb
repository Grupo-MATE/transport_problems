# %%
using Random
Random.seed!(784);

# Crear las estaciones y sus asignaciones aleatoriamente
n = 2;
z = sortslices(rand(n,2), dims = 1);
print(z)
d = round.(10*rand(n))
print(d)
# Out:
# [0.6452016105768037 0.4707431436048797; 0.8587157530866789 0.7917734764757278][8.0, 1.0]

# %%
# Repetir los puntos z_i, d_i veces (para la distribución)
p = repeat(z[1,:]', Int(d[1]))
for i in 2:n
    p = vcat(p, repeat(z[i,:]', Int(d[i])) )
end
print(p)
# Out:
# [0.6452016105768037 0.4707431436048797; 0.6452016105768037 0.4707431436048797; 0.6452016105768037 0.4707431436048797; 0.6452016105768037 0.4707431436048797; 0.6452016105768037 0.4707431436048797; 0.6452016105768037 0.4707431436048797; 0.6452016105768037 0.4707431436048797; 0.6452016105768037 0.4707431436048797; 0.8587157530866789 0.7917734764757278]

# %%
using Plots
scatter(p[:,1], p[:,2], aspect_ratio=:equal, markersize = 3, legend = :topright) #Grafica los origenes, con color por destino

# %%
using KernelDensity
B = kde(p)
# Out:
# BivariateKDE{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}}}(0.48009692792116676:0.0021322490502790163:1.023820435742316, 0.22249911345112341:0.003205954483052395:1.0400175066294841, [6.793358617277964e-6 8.124250170115505e-6 … 4.912677195076419e-6 5.735265037813946e-6; 8.124250169876113e-6 9.799254011979425e-6 … 5.704755954499992e-6 6.775265688110498e-6; … ; 4.912677194609562e-6 5.704755954257998e-6 … 3.900765694070905e-6 4.318329649937239e-6; 5.735265038254132e-6 6.775265688816964e-6 … 4.3183296507785796e-6 4.925796199308982e-6])

# %%
plot(B.density)

# %%
plot(B.density')
